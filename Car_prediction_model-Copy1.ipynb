# %%
import pandas as pd

# %%
df = pd.read_csv('car details v3.csv')

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
# We have mileage in string , so we will split the "kmpl" part to just get the numeric mileage
mil = df['mileage'].str.split(" ", n = 1,expand=True)
df['mil']=mil[0]

# %%
temp = df

# %%
eng = df['engine'].str.split(" ", n = 1, expand=True)
df['eng'] = eng[0]

# %%
mpow = df['max_power'].str.split(" ", n = 1, expand=True)
df['max_power']=mpow[0]

# %%
df.drop(columns=['mileage','engine','torque'],inplace=True)

# %%
df.drop(columns=['name'])
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014         450000     145500  Diesel  Individual       Manual
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner max_power  seats    mil   eng
# 0              First Owner        74    5.0   23.4  1248
# ...

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# max_power        215
# seats            221
# mil              221
# eng              221
# dtype: int64

# %%
df['seats'].value_counts()
# Out:
# 5.0     6254
# 7.0     1120
# 8.0      236
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: seats, dtype: int64

# %%
df['seats'] = df['seats'].fillna(df['seats'].mode()[0])

# %%
df['seats'].isnull().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'max_power', 'seats', 'mil', 'eng'],
#       dtype='object')

# %%
df['mil'] = df['mil'].astype(float)
df['eng'] = df['eng'].astype(float)

# %%
df.drop(columns = ['max_power'], inplace=True)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner  seats    mil     eng
# 0  Individual       Manual   First Owner    5.0  23.40  1248.0
# 1  Individual       Manual  Second Owner    5.0  21.14  1498.0
# 2  Individual       Manual   Third Owner    5.0  17.70  1497.0
# 3  Individual       Manual   First Owner    5.0  23.00  1396.0
# 4  Individual       Manual   First Owner    5.0  16.10  1298.0

# %%
print(df['owner'].unique())
# Out:
# ['First Owner' 'Second Owner' 'Third Owner' 'Fourth & Above Owner'
#  'Test Drive Car']

# %%
print(df['transmission'].unique())
# Out:
# ['Manual' 'Automatic']

# %%
# Check missing values or Null values
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# seats            0
# mil              0
# eng              0
# dtype: int64

# %%
na_mil = df['mil'].mean()
na_mil
# Out:
# 19.418783356519516

# %%
na_eng = df['eng'].mean()
na_eng
# Out:
# 1458.625015808777

# %%
df['mil'].fillna(df['mil'].mean(),inplace=True)

# %%
df['eng'].fillna(df['eng'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# seats            0
# mil              0
# eng              0
# dtype: int64

# %%
df.drop(columns=['name'])
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014         450000     145500  Diesel  Individual       Manual
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner  seats    mil     eng
# 0              First Owner    5.0  23.40  1248.0
# ...

# %%
Final_data = df[['year','selling_price','km_driven',
       'fuel', 'seller_type', 'transmission', 'owner','seats','mil','eng']]

# %%
Final_data
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014         450000     145500  Diesel  Individual       Manual
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner  seats    mil     eng
# 0              First Owner    5.0  23.40  1248.0
# ...

# %%
Final_data['Current_Year'] = 2021

# %%
Final_data['No_Years'] = Final_data['Current_Year'] - Final_data['year']

# %%
Final_data
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014         450000     145500  Diesel  Individual       Manual
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner  seats    mil     eng  Current_Year  No_Years
# ...

# %%
# Dropping Year and the Current_Year variables from the dataset
# No_years gives more intuition
Final_data.drop(['year'],axis=1,inplace=True)

# %%
Final_data.drop(['Current_Year'],axis=1, inplace=True)

# %%
Final_data
# Out:
#       selling_price  km_driven    fuel seller_type transmission  \
# 0            450000     145500  Diesel  Individual       Manual
# 1            370000     120000  Diesel  Individual       Manual
# 2            158000     140000  Petrol  Individual       Manual
# 3            225000     127000  Diesel  Individual       Manual
# 4            130000     120000  Petrol  Individual       Manual
# ...             ...        ...     ...         ...          ...
# 8123         320000     110000  Petrol  Individual       Manual
# 8124         135000     119000  Diesel  Individual       Manual
# 8125         382000     120000  Diesel  Individual       Manual
# 8126         290000      25000  Diesel  Individual       Manual
# 8127         290000      25000  Diesel  Individual       Manual
#
#                      owner  seats    mil     eng  No_Years
# 0              First Owner    5.0  23.40  1248.0         7
# 1             Second Owner    5.0  21.14  1498.0         7
# ...

# %%
Final_data=pd.get_dummies(Final_data,drop_first=True)
# drop_first = True will remove dummy variable trap; it will remove correlated attributes

# %%
Final_data.head()
# Out:
#    selling_price  km_driven  seats    mil     eng  No_Years  fuel_Diesel  \
# 0         450000     145500    5.0  23.40  1248.0         7            1
# 1         370000     120000    5.0  21.14  1498.0         7            1
# 2         158000     140000    5.0  17.70  1497.0        15            0
# 3         225000     127000    5.0  23.00  1396.0        11            1
# 4         130000     120000    5.0  16.10  1298.0        14            0
#
#    fuel_LPG  fuel_Petrol  seller_type_Individual  \
# 0         0            0                       1
# 1         0            0                       1
# 2         0            1                       1
# 3         0            0                       1
# 4         0            1                       1
#
#    seller_type_Trustmark Dealer  transmission_Manual  \
# 0                             0                    1
# 1                             0                    1
# 2                             0                    1
# ...

# %%
# Veiwing correlation between the variables
Final_data.corr()
# Out:
#                               selling_price  km_driven     seats       mil  \
# selling_price                      1.000000  -0.225534  0.047135 -0.125454
# km_driven                         -0.225534   1.000000  0.219860 -0.171426
# seats                              0.047135   0.219860  1.000000 -0.450930
# mil                               -0.125454  -0.171426 -0.450930  1.000000
# eng                                0.453567   0.203954  0.608750 -0.575831
# No_Years                          -0.414092   0.418006 -0.010222 -0.310383
# fuel_Diesel                        0.206521   0.266368  0.350145  0.059676
# fuel_LPG                          -0.037222   0.023458 -0.029282 -0.013343
# fuel_Petrol                       -0.195975  -0.269802 -0.341146 -0.073616
# seller_type_Individual            -0.386244   0.204736  0.077818  0.011640
# seller_type_Trustmark Dealer       0.035084  -0.084282 -0.026004 -0.036175
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(Final_data)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# creating heatmap for the dataset
corrmat = Final_data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
hm = sns.heatmap(Final_data[top_corr_features].corr(),annot = True, cmap="RdYlGn")

# %%
# GREEN color says that it is highly positively correlated and Red color says that it is highly negatively correlated

# %%
# Independent Variables
X=Final_data.iloc[:,1:]
X.head()
# Out:
#    km_driven  seats    mil     eng  No_Years  fuel_Diesel  fuel_LPG  \
# 0     145500    5.0  23.40  1248.0         7            1         0
# 1     120000    5.0  21.14  1498.0         7            1         0
# 2     140000    5.0  17.70  1497.0        15            0         0
# 3     127000    5.0  23.00  1396.0        11            1         0
# 4     120000    5.0  16.10  1298.0        14            0         0
#
#    fuel_Petrol  seller_type_Individual  seller_type_Trustmark Dealer  \
# 0            0                       1                             0
# 1            0                       1                             0
# 2            1                       1                             0
# 3            0                       1                             0
# 4            1                       1                             0
#
#    transmission_Manual  owner_Fourth & Above Owner  owner_Second Owner  \
# ...

# %%
# Dependent Variables
y=Final_data.iloc[:,0]
y.head()
# Out:
# 0    450000
# 1    370000
# 2    158000
# 3    225000
# 4    130000
# Name: selling_price, dtype: int64

# %%
##### Feature Importance
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [7.97429868e-02 2.07578847e-02 5.72291911e-02 1.86467533e-01
#  1.62663680e-01 4.87473877e-02 6.27511038e-06 3.60092795e-02
#  4.24558835e-02 1.14901221e-03 3.46893347e-01 3.32428524e-04
#  7.61243321e-03 8.31627002e-03 1.61640798e-03]

# %%
# plotting to see which are the top features
feat_importances = pd.Series(model.feature_importances_,index=X.columns)
feat_importances.plot(kind='barh')
plt.show(6)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25)

# %%
X_train.shape
# Out:
# (6096, 15)

# %%
from sklearn.ensemble import RandomForestRegressor
import numpy as np
regressor = RandomForestRegressor()

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]

# max_depth.append(None)

# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [5, 10, 15, 20, 25, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
### Creating a base model
rf = RandomForestRegressor()
from sklearn.model_selection import RandomizedSearchCV

# %%
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   6.2s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.1s remaining:    0.0s
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   6.6s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# [CV]  n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10, total=   5.8s
# [CV] n_estimators=900, min_samples_split=5, min_samples_leaf=5, max_features=sqrt, max_depth=10
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 25}

# %%
rf_random.best_score_
# Out:
# -30903692180.900337

# %%
# Now predicting our data on Test data
predictions = rf_random.predict(X_test)

# %%
predictions
# Out:
# array([ 388208.42933333, 2475000.        ,  282204.07575   , ...,
#         504825.23871453,  173240.32933333,  275898.33201515])

# %%
sns.distplot(y_test-predictions)

### the difference between the actual and normal values are giving us a normal distribution.
# this indicates that our model is performing much better than we expected.

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MSE', metrics.mean_squared_error(y_test,predictions))
print('MAE', metrics.mean_absolute_error(y_test,predictions))
print('RMSE', np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MSE 60469468944.188126
# MAE 85647.49345925184
# RMSE 245905.40649645776

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_model1.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)
